# %%
from bs4 import BeautifulSoup as bs
import requests
import pypdf

# %%
url = "https://www.google.com.pk/books/edition/The_Pragmatic_Programmer/5wBQEp6ruIAC?hl=en&gbpv=1&pg=PR9&printsec=frontcover"
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
soup = bs(req.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
img = soup.select("div.selection_layer")
img
# Out:
# []
